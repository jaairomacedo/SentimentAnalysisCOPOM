# %% [markdown]
# # Projeto de análise das Atas do Copom

# %% [markdown]
# ## Pacotes

# %%
from bs4 import BeautifulSoup as Soup
import requests #Web Scraping
import json #Tranformar dados em Json
import pandas as pd #Tratamento de dados
from urllib.parse import urljoin #Concatenar URLs
from PyPDF2 import PdfFileReader #Extração de textos dos PDFs
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jairo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jairo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Web Scraping

# %%
url = "https://www.bcb.gov.br/api/servico/sitebcb/copomminutes/ultimas?quantidade=1000&filtro="

payload = {}
headers = {
  'authority': 'www.bcb.gov.br',
  'accept': 'application/json, text/plain, */*',
  'accept-language': 'pt-BR,pt;q=0.9,en;q=0.8',
  'cookie': 'BIGipServer~site_internet_azure_p_as3~site_internet_azure_p~pool_cluster_www_443_p=rd2o00000000000000000000ffffc8dad042o443; _gid=GA1.3.1928060446.1698534390; bcb-aceitacookie=true; ASPSESSIONIDSUCRQSRS=PEOGHEBCHPDGAJJMICPJOLJH; _ga_TPS4R7DC1S=GS1.1.1698534389.3.1.1698534828.59.0.0; _ga=GA1.1.1533208214.1698443841',
  'if-none-match': '"875fd9f3-281a-438b-946f-26ddad07bf86"',
  'referer': 'https://www.bcb.gov.br/en/publications/copomminutes/cronologicos',
  'sec-ch-ua': '"Chromium";v="118", "Microsoft Edge";v="118", "Not=A?Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.69'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"conteudo":[{"DataReferencia":"2023-11-01T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"258th Meeting - October 31 - November 1, 2023","Url":"/content/copom/copomminutes/MINUTES 258.pdf","LinkPagina":"/en/publications/copomminutes/01112023","EsconderDataReferencia":true},{"DataReferencia":"2023-09-20T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"257th Meeting - September 19-20, 2023","Url":"/content/copom/copomminutes/MINUTES 257.pdf","LinkPagina":"/en/publications/copomminutes/20092023","EsconderDataReferencia":true},{"DataReferencia":"2023-08-02T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"256th Meeting - August 1-2, 2023","Url":"/content/copom/copomminutes/MINUTES 256.pdf","LinkPagina":"/en/publications/copomminutes/02082023","EsconderDataReferencia":true},{"DataReferencia":"2023-06-21T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"255th Meeting - June 20-21, 2023","Url":"/content/copom/copomminutes/Minutes 255.pdf","LinkPagina":"/en/publications/copomminutes/21062023","EsconderDataReferencia":true},{"DataReferencia":"2023-05-03T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"254th Meeting - May 2-3, 2023","Url":"/content/copom/copomminutes/MINUTES 254.pdf","LinkPagina":"/en/publications/copomminutes/03052023","EsconderDataReferencia":true},{"DataReferencia":"2023-03-22T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"253rd Meeting - March 21-22, 2023","Url":"/content/copom/copomminutes/MINUTES 253.pdf","LinkPagina":"/en/publications/copomminutes/22032023","EsconderDataReferencia":true},{"DataReferencia":"2023-02-01T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"252nd Meeting - January 31 - February 1, 2023","Url":"/content/copom/copomminutes/MINUTES 252.pdf","LinkPagina":"/en/publications/copomminutes/01022023","EsconderDataReferencia":true},{"DataReferencia":"2022-12-07T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"251st Meeting - December 6-7, 2022","Url":"/content/copom/copomminutes/Minutes 251.pdf","LinkPagina":"/en/publications/copomminutes/07122022","EsconderDataReferencia":true},{"DataReferencia":"2022-10-26T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"250th Meeting - October 25-26, 2022","Url":"/content/copom/copomminutes/Minutes 250.pdf","LinkPagina":"/en/publications/copomminutes/26102022","EsconderDataReferencia":true},{"DataReferencia":"2022-09-21T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"249th Meeting - September 20-21, 2022","Url":"/content/copom/copomminutes/MINUTES 249.pdf","LinkPagina":"/en/publications/copomminutes/21092022","EsconderDataReferencia":true},{"DataReferencia":"2022-08-03T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"248th Meeting - August 2-3, 2022","Url":"/content/copom/copomminutes/MINUTES 248.pdf","LinkPagina":"/en/publications/copomminutes/03082022","EsconderDataReferencia":true},{"DataReferencia":"2022-06-15T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo":"247th Meeting - June 14-15, 2022","Url":"/content/copom/copomminutes/Minutes 247.pdf","LinkPagina":"/en/publications/copomminutes/15062022","EsconderDataReferencia":true},{"DataReferencia":"2022-05-04T03:00:00Z","ImagemCapa":"/content/publications/PublishingImages/Capas/copomminutes/capa-copomminutes.png","Titulo" ...

# %% [markdown]
# ## Tratamento de dados

# %%
dados=response.json() #Dados em Json
dados

# %%
df = pd.DataFrame(dados['conteudo']) #DataFrame dos Dados
df

# %%
df1 = df.drop(['ImagemCapa', 'EsconderDataReferencia'], axis=1) #Limpando as colunas desnecessárias
df1

# %%
df1 = df1.dropna(axis=1)
df1

# %%
# Função para criar coluna com os números das reuniões
def extrair_numero(text):
    match = re.search(r'(\d+)', text)  # Encontra a primeira sequência de dígitos
    if match:
        return int(match.group(1))  # Converte para int
    return None

# %%
df1['Numero'] = df['Titulo'].apply(extrair_numero)
df1

# %%
# Concatenando a coluna 'URL' com a parte fixa
df1['URL_completa'] ='https://www.bcb.gov.br' + df1['Url']

# Exibindo o DataFrame
df1.head(2)
# Out:
#          DataReferencia                                         Titulo  \
# 0  2023-11-01T03:00:00Z  258th Meeting - October 31 - November 1, 2023
# 1  2023-09-20T03:00:00Z          257th Meeting - September 19-20, 2023
#
#                                            Url  \
# 0  /content/copom/copomminutes/MINUTES 258.pdf
# 1  /content/copom/copomminutes/MINUTES 257.pdf
#
#                                LinkPagina  Numero  \
# 0  /en/publications/copomminutes/01112023   258.0
# 1  /en/publications/copomminutes/20092023   257.0
#
#                                         URL_completa
# 0  https://www.bcb.gov.br/content/copom/copomminu...
# 1  https://www.bcb.gov.br/content/copom/copomminu...

# %% [markdown]
# ## Extração dos textos a partir dos PDF's

# %%
def extrair_texto_de_pdf(link, pagina_inicial=3):
    try:
        response = requests.get(link)
        if response.status_code == 200:
            with open("temp.pdf", "wb") as pdf_file:
                pdf_file.write(response.content)

            pdf_reader = PdfReader("temp.pdf")
            texto = ""
            for page_num in range(pagina_inicial - 1, len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                texto += page.extract_text()

            return texto
    except Exception as e:
        print(f"Erro ao extrair texto do PDF: {e}")
        return None

# %%
df1['texto_extraido'] = df1['URL_completa'].apply(extrair_texto_de_pdf)

# %% [markdown]
# ## Tratamento dos textos

# %%
df1.columns
# Out:
# Index(['DataReferencia', 'Titulo', 'Url', 'LinkPagina', 'Numero',
#        'URL_completa'],
#       dtype='object')

# %%
df1.drop(214)

# %%
df1["texto_extraido"]

# %%
#Tabela com textos
print(df1["texto_extraido"].iloc[0])

# %%
# Palavras a serem excluídas
palavras_excluir = ['copom', 'month', 'year',]

# %%
stop_words = set(stopwords.words('english'))

# %%
df1.loc[:, 'texto_extraido'] = df1['texto_extraido'].apply(lambda x: ' '.join([word.lower() for word in word_tokenize(x) if word.isalpha() and len(word) > 2 and word.lower() not in stop_words and word.lower() not in palavras_excluir]))

# %%
word_counts = Counter(' '.join(df1['texto_extraido']).split())

# %%
top_words = word_counts.most_common(10)

# %%
top_words = word_counts.most_common(5)
top_words
# Out:
# [('inflation', 6720),
#  ('rate', 4809),
#  ('prices', 4171),
#  ('increased', 3388),
#  ('billion', 3318)]

# %%
words, counts = zip(*top_words)
plt.bar(words, counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words')
plt.show()
